# %%
from src.ml.modelo_ventas import entrenar_y_predecir_ventas_diarias
from src.ingestion.validator import cargar_csv

df = cargar_csv("C:\DATA\My Documents\Drive\MSc en Data Science\A2 - Seguimiento PAPD\Ciclo 4\Product Development\Tareas\Hackathon\datasets\dataset_noviembre_2025.csv")
# Si ya tienes filtrado por periodo, úsalo; si no, pasa df directo por ahora:
resultados = entrenar_y_predecir_ventas_diarias(df)

print(resultados["metricas_modelo"])
print(resultados["predicciones_futuras"].head())
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\vmrod\AppData\Local\Temp\ipykernel_39056\2501495900.py:4: SyntaxWarning: invalid escape sequence '\D'
#   df = cargar_csv("C:\DATA\My Documents\Drive\MSc en Data Science\A2 - Seguimiento PAPD\Ciclo 4\Product Development\Tareas\Hackathon\datasets\dataset_noviembre_2025.csv")
# C:\Users\vmrod\AppData\Local\Temp\ipykernel_39056\2501495900.py:4: SyntaxWarning: invalid escape sequence '\D'
#   df = cargar_csv("C:\DATA\My Documents\Drive\MSc en Data Science\A2 - Seguimiento PAPD\Ciclo 4\Product Development\Tareas\Hackathon\datasets\dataset_noviembre_2025.csv")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.ml.modelo_ventas import entrenar_y_predecir_ventas_diarias
#       2 from src.ingestion.validator import cargar_csv
# ...
